# %%
from selenium import  webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.common.keys import Keys
import pandas as pd

# %%
chrome_options = webdriver.ChromeOptions()
### This blocks images and javascript requests
chrome_prefs = {
    "profile.default_content_setting_values": {
        "images": 2,
        "javascript": 2,
    }
}
chrome_options.experimental_options["prefs"] = chrome_prefs
###

driver = webdriver.Chrome()

url = 'https://housing.com/in/buy/searches/H4M86P5eetqxj34ghuz32h'
driver.get(url)


time.sleep(3)




try:
    element = driver.find_element(By.TAG_NAME,value='body')
    while True:
        element.send_keys(Keys.PAGE_DOWN)
        time.sleep(1)
        page_41 = driver.find_element(By.CLASS_NAME,value='css-1nm99ps')


        m= '754'
        if m in page_41.text :
            break
except Exception as e:
    print('step1:',e)
    pass
#//*[@id="innerApp"]/div[3]/div[2]/div[1]
#css-v64o2m
#//*[@id="srp-10"]/div/div[2]/div[1]/span

#//*[@id="srp-10"]/div/div[2]/di

'''   s= driver.find_element( By.CLASS_NAME ,value='css-18rodr0')
print(s.text    '''


try:
    bigbox = driver.find_elements(By.CLASS_NAME,value='css-1nr7r9e')


#    total_price=[]
    total_name=[]
    total_address = []
    total_sqft=[]
    total_avg_sqft = []
    total_owners = []
    emi_option=[]

    for box in bigbox :
#        price = box.find_element(By.CLASS_NAME,value='css-18rodr0')
        name = box.find_element(By.CLASS_NAME,value='css-zekqfr')
        address = box.find_element(By.CLASS_NAME,value='css-4in8py')
        sq_ft = box.find_element(By.CLASS_NAME,value='css-1ty8tu4')

        owner = box.find_element(By.CLASS_NAME,value='css-wni7av')
        emi = box.find_element(By.CLASS_NAME,value='css-70qvj9')


        total_name.append(name.text)
#        total_price.append(price.text)
        total_address.append(address.text)
        total_sqft.append(sq_ft.text)
        emi_option.append(emi.text)

        total_owners.append(owner.text)
except Exception as e:
    print('step2:',e)


    pass
'''print(total_name)
print(total_price)
print(total_address)
print(total_sqft)

print(total_owners)
print(emi_option)'''


print('name',len(total_name))
#print('price',len(total_price))
print('address',len(total_address))
print('sqft',len(total_sqft))
print('owners',len(total_owners))
print('emi',len(emi_option))

try:
    df = pd.DataFrame()
    df['name']=total_name
#    df['price']=total_price
    df['address']=total_address
    df['sq_ft']=total_sqft
    df['owners']=total_owners
    df['emi']=emi_option
except Exception as e:
    print('step3',e)
    pass


df.to_csv('df7')
# Out:
# name 753
# address 753
# sqft 753
# owners 753
# emi 753

# %%
df['housetype'] = 'Apartment'
df['house_condition'] = 'old'

# %%
import pandas as pd

# %%
df = pd.read_csv('housing_data7',index_col=0)

# %%
df['housetype'] = 'Independent_house'
df['house_condition'] = 'old'

# %%
df
# Out:
#                                                   name  \
# 0      2 BHK Independent House for sale in Nashik Road
# 1    2 BHK Independent House for sale in Pathardi P...
# 2                          Infinity Madhuban Residency
# 3                             Prabhat Vandan Apartment
# 4                          Shree Infra Vraj Bungalow A
# ..                                                 ...
# 748                                    Geeta Shivdhara
# 749             Atharvashree Shree Atharv Park Phase I
# 750                           Shree Prakash Le Regalia
# 751                       Nirman Green Cottages Villas
# 752                              Ashoka Kalpataru Ph 1
#
#                                                address  \
# 0    Aditya Apartment ,Swami Samarth Nagar, Nashik ...
# 1    Vasant Bahar,Pathardi Gaon, Pathardi Phata,Nashik
# 2                              Madhuban Colony, Nashik
# 3                           Janata Raja Colony, Nashik
# 4                                Deepali Nagar, Nashik
# ..                                                 ...
# 748                     Vasantdadanagar, Adgaon,Nashik
# 749                  Samarth Nagar, Makhmalabad,Nashik
# 750                             Bhor Town Ship, Nashik
# 751                                   Chandshi, Nashik
# 752                               Medage Nagar, Nashik
#
#                                  sq_ft                                 owners  \
# 0                            835 sq.ft                            DisposalHub
# 1                           1500 sq.ft                  Dadasaheb Suryawanshi
# 2                      1, 2 BHK Villas       Infinity Heights Private Limited
# 3        2, 3 BHK Apartment,Penthouses              Prabhat Developers Nashik
# 4                      2, 3 BHK Villas                    Shree Infra Project
# ..                                 ...                                    ...
# 748                        2 BHK Villa                         Geeta Buildcon
# 749                        2 BHK Villa  Atharvashree Buildmat Private Limited
# 750  1, 2, 3 BHK Apartment, Penthouses               Shree Prakash Developers
# 751                    2, 3 BHK Villas                           Nirman Group
# 752                        1 BHK Villa                          Ashoka Realty
#
#                                             emi          housetype  \
# 0               ₹30.0 L\nEMI starts at ₹15.89 K  Independent_house
# 1               ₹32.0 L\nEMI starts at ₹16.95 K  Independent_house
# 2     ₹11.52 L - 16.86 L\nEMI starts at ₹6.10 K  Independent_house
# 3     ₹21.42 L - 38.5 L\nEMI starts at ₹11.34 K  Independent_house
# 4    ₹32.89 L - 42.54 L\nEMI starts at ₹17.42 K  Independent_house
# ..                                          ...                ...
# 748                            Price on Request  Independent_house
# 749            ₹34.32 L\nEMI starts at ₹18.17 K  Independent_house
# 750                            Price on Request  Independent_house
# 751                            Price on Request  Independent_house
# 752             ₹11.38 L\nEMI starts at ₹6.02 K  Independent_house
#
#     house_condition
# 0               old
# 1               old
# 2               old
# 3               old
# 4               old
# ..              ...
# 748             old
# 749             old
# 750             old
# 751             old
# 752             old
#
# [753 rows x 7 columns]

# %%
df.to_csv('housing_data7')

# %%
df.head()
# Out:
#                                                 name  \
# 0    2 BHK Independent House for sale in Nashik Road
# 1  2 BHK Independent House for sale in Pathardi P...
# 2                        Infinity Madhuban Residency
# 3                           Prabhat Vandan Apartment
# 4                        Shree Infra Vraj Bungalow A
#
#                                              address  \
# 0  Aditya Apartment ,Swami Samarth Nagar, Nashik ...
# 1  Vasant Bahar,Pathardi Gaon, Pathardi Phata,Nashik
# 2                            Madhuban Colony, Nashik
# 3                         Janata Raja Colony, Nashik
# 4                              Deepali Nagar, Nashik
#
#                            sq_ft                            owners  \
# 0                      835 sq.ft                       DisposalHub
# 1                     1500 sq.ft             Dadasaheb Suryawanshi
# 2                1, 2 BHK Villas  Infinity Heights Private Limited
# 3  2, 3 BHK Apartment,Penthouses         Prabhat Developers Nashik
# 4                2, 3 BHK Villas               Shree Infra Project
#
#                                           emi          housetype  \
# 0             ₹30.0 L\nEMI starts at ₹15.89 K  Independent_house
# 1             ₹32.0 L\nEMI starts at ₹16.95 K  Independent_house
# 2   ₹11.52 L - 16.86 L\nEMI starts at ₹6.10 K  Independent_house
# 3   ₹21.42 L - 38.5 L\nEMI starts at ₹11.34 K  Independent_house
# 4  ₹32.89 L - 42.54 L\nEMI starts at ₹17.42 K  Independent_house
#
#   house_condition
# 0             old
# 1             old
# 2             old
# 3             old
# 4             old

# %%
df.describe()
# Out:
#                                                    name              address  \
# count                                               753                  753
# unique                                              349                  272
# top     2 BHK Independent House for sale in Nashik Road  Nashik Road, Nashik
# freq                                                 32                   60
#
#              sq_ft     owners                              emi
# count          753        753                              753
# unique         257        500                              171
# top     1000 sq.ft  Mr Sanjay  ₹30.0 L\nEMI starts at ₹15.89 K
# freq            40         75                               39

# %%
import pandas as pd

# %%
df = pd.read_csv('housing_data7',index_col=0)
df
# Out:
#                                                   name  \
# 0      2 BHK Independent House for sale in Nashik Road
# 1    2 BHK Independent House for sale in Pathardi P...
# 2                          Infinity Madhuban Residency
# 3                             Prabhat Vandan Apartment
# 4                          Shree Infra Vraj Bungalow A
# ..                                                 ...
# 748                                    Geeta Shivdhara
# 749             Atharvashree Shree Atharv Park Phase I
# 750                           Shree Prakash Le Regalia
# 751                       Nirman Green Cottages Villas
# 752                              Ashoka Kalpataru Ph 1
#
#                                                address  \
# 0    Aditya Apartment ,Swami Samarth Nagar, Nashik ...
# 1    Vasant Bahar,Pathardi Gaon, Pathardi Phata,Nashik
# 2                              Madhuban Colony, Nashik
# 3                           Janata Raja Colony, Nashik
# 4                                Deepali Nagar, Nashik
# ..                                                 ...
# 748                     Vasantdadanagar, Adgaon,Nashik
# 749                  Samarth Nagar, Makhmalabad,Nashik
# 750                             Bhor Town Ship, Nashik
# 751                                   Chandshi, Nashik
# 752                               Medage Nagar, Nashik
#
#                                  sq_ft                                 owners  \
# 0                            835 sq.ft                            DisposalHub
# 1                           1500 sq.ft                  Dadasaheb Suryawanshi
# 2                      1, 2 BHK Villas       Infinity Heights Private Limited
# 3        2, 3 BHK Apartment,Penthouses              Prabhat Developers Nashik
# 4                      2, 3 BHK Villas                    Shree Infra Project
# ..                                 ...                                    ...
# 748                        2 BHK Villa                         Geeta Buildcon
# 749                        2 BHK Villa  Atharvashree Buildmat Private Limited
# 750  1, 2, 3 BHK Apartment, Penthouses               Shree Prakash Developers
# 751                    2, 3 BHK Villas                           Nirman Group
# 752                        1 BHK Villa                          Ashoka Realty
#
#                                             emi          housetype  \
# 0               ₹30.0 L\nEMI starts at ₹15.89 K  Independent_house
# 1               ₹32.0 L\nEMI starts at ₹16.95 K  Independent_house
# 2     ₹11.52 L - 16.86 L\nEMI starts at ₹6.10 K  Independent_house
# 3     ₹21.42 L - 38.5 L\nEMI starts at ₹11.34 K  Independent_house
# 4    ₹32.89 L - 42.54 L\nEMI starts at ₹17.42 K  Independent_house
# ..                                          ...                ...
# 748                            Price on Request  Independent_house
# 749            ₹34.32 L\nEMI starts at ₹18.17 K  Independent_house
# 750                            Price on Request  Independent_house
# 751                            Price on Request  Independent_house
# 752             ₹11.38 L\nEMI starts at ₹6.02 K  Independent_house
#
#     house_condition
# 0               old
# 1               old
# 2               old
# 3               old
# 4               old
# ..              ...
# 748             old
# 749             old
# 750             old
# 751             old
# 752             old
#
# [753 rows x 7 columns]

# %%
temp_df = df.loc[:,['name','sq_ft']]
temp_df
# Out:
#                                                   name  \
# 0      2 BHK Independent House for sale in Nashik Road
# 1    2 BHK Independent House for sale in Pathardi P...
# 2                          Infinity Madhuban Residency
# 3                             Prabhat Vandan Apartment
# 4                          Shree Infra Vraj Bungalow A
# ..                                                 ...
# 748                                    Geeta Shivdhara
# 749             Atharvashree Shree Atharv Park Phase I
# 750                           Shree Prakash Le Regalia
# 751                       Nirman Green Cottages Villas
# 752                              Ashoka Kalpataru Ph 1
#
#                                  sq_ft
# 0                            835 sq.ft
# 1                           1500 sq.ft
# 2                      1, 2 BHK Villas
# 3        2, 3 BHK Apartment,Penthouses
# 4                      2, 3 BHK Villas
# ..                                 ...
# 748                        2 BHK Villa
# 749                        2 BHK Villa
# 750  1, 2, 3 BHK Apartment, Penthouses
# 751                    2, 3 BHK Villas
# 752                        1 BHK Villa
#
# [753 rows x 2 columns]

# %%
def name_splitter(value):
    if 'BHK' in value:
        return value.split(sep=' BHK')[0]
    else:
        value = ''
        return value

# %%
temp_df['BHK'] = temp_df['name'].apply(name_splitter)

# %%
temp_df['BHK'].unique()
# Out:
# array(['2', '', '1', '3', '8', '5', '7', '4', '6', '10'], dtype=object)

# %%
temp_df['BHK1'] = temp_df['sq_ft'].apply(name_splitter)

# %%
temp_df.BHK1.unique()
# Out:
# array(['', '1, 2', '2, 3', '1, 2, 3', '2', '3', '2, 3, 4', '3, 3.5', '4',
#        '3, 5, 7', '7', '3, 4', '3.5', '5', '2, 2.5', '1'], dtype=object)

# %%
temp_df['final_BHK']= temp_df['BHK']+temp_df['BHK1']

# %%
def splitting_sqft(value):
    if 'sq' in value:
        return value.split()[0]
    else:
        value = 'NA'
        return value

# %%
temp_df['total_sqft'] = temp_df['sq_ft'].apply(splitting_sqft)

# %%
temp_df.total_sqft.unique()
# Out:
# array(['835', '1500', 'NA', '850', '1300', '1100', '910', '1650', '1252',
#        '10000', '1150', '950', '2500', '1250', '1400', '2300', '1800',
#        '500', '1000', '800', '3200', '980', '1200', '650', '900', '1450',
#        '863', '560', '1141', '737', '3600', '2600', '1022', '2044', '840',
#        '780', '750', '2000', '645', '365', '3500', '1298', '1588', '2400',
#        '345', '1040', '1080', '885', '3560', '770', '1511', '906', '680',
#        '2100', '720', '3000', '1411', '1350', '1655', '3800', '845',
#        '1520', '550', '830', '756', '1600', '592', '525', '690', '1380',
#        '5616', '1312', '804', '1117', '600', '2260', '1260', '2553',
#        '960', '2700', '1578', '1154', '1872', '1137', '3300', '1045',
#        '1622', '1660', '1066', '874', '40000', '5000', '875', '925',
#        '1700', '865', '160', '150', '370', '1185', '1120', '450', '660',
#        '1065', '2250', '1992', '1505', '300', '775', '710', '1356', '337',
#        '700', '480', '1125', '1610', '521', '627', '1050', '4000', '880',
#        '997', '1164', '1750', '1880', '375', '824', '2850', '1950', '400',
#        '1850', '420', '1585', '320', '755', '2074', '608', '2800', '2065',
#        '1593', '975', '350', '4900', '1128', '905', '515', '1220', '965',
#        '1095', '1255', '1752', '4200', '321', '1160', '1490', '1485',
#        '836', '1280', '1360', '1550', '1070', '1071', '13000', '1670',
#        '561', '1594', '887', '990', '1668', '807', '1635', '1921', '1270',
#        '1410', '1538', '2200', '1425', '3150', '1180', '2239', '1089',
#        '930', '1503', '1557', '2430', '820', '2493', '1290', '715', '565',
#        '585', '590', '675', '1238', '1455', '1900', '945', '1048', '510',
#        '816', '1390', '860', '1009', '1430', '964', '1230', '1530',
#        '1443', '2002', '1603', '1875', '4095', '3412', '1460', '978',
#        '1580', '1512', '735', '1372', '665', '1540', '2140', '1278',
#        '1023', '822', '854', '536', '1725', '2310', '640', '1740', '970',
#        '1325', '924', '1420', '1475'], dtype=object)

# %%
temp_df
# Out:
#                                                   name  \
# 0      2 BHK Independent House for sale in Nashik Road
# 1    2 BHK Independent House for sale in Pathardi P...
# 2                          Infinity Madhuban Residency
# 3                             Prabhat Vandan Apartment
# 4                          Shree Infra Vraj Bungalow A
# ..                                                 ...
# 748                                    Geeta Shivdhara
# 749             Atharvashree Shree Atharv Park Phase I
# 750                           Shree Prakash Le Regalia
# 751                       Nirman Green Cottages Villas
# 752                              Ashoka Kalpataru Ph 1
#
#                                  sq_ft BHK     BHK1 final_BHK total_sqft
# 0                            835 sq.ft   2                  2        835
# 1                           1500 sq.ft   2                  2       1500
# 2                      1, 2 BHK Villas         1, 2      1, 2         NA
# 3        2, 3 BHK Apartment,Penthouses         2, 3      2, 3         NA
# 4                      2, 3 BHK Villas         2, 3      2, 3         NA
# ..                                 ...  ..      ...       ...        ...
# 748                        2 BHK Villa            2         2         NA
# 749                        2 BHK Villa            2         2         NA
# 750  1, 2, 3 BHK Apartment, Penthouses      1, 2, 3   1, 2, 3         NA
# 751                    2, 3 BHK Villas         2, 3      2, 3         NA
# 752                        1 BHK Villa            1         1         NA
#
# [753 rows x 6 columns]

# %%
import regex as re
def min_price(value):
    
    min_price = re.findall(r"[-+]?\d*\.\d+|\d+",value)
    

    if 'Cr\nEMI starts at'in value:
        value2 = float(min_price[0])*100
        return round(value2,ndigits=1)
    elif 'Price on Request' in value:
        return 'Price on Request'
    else:
        return min_price[0]

# %%
df['price'] = df['emi'].apply(min_price)

# %%
new=temp_df.loc[:,['final_BHK','total_sqft']]

# %%
df2 =  df.join( new)

# %%
def emi_splitter(value):
 #   if 'Cr\nEMI starts at'in value:
#        value = float(value.split(sep=' ')[0])*100
 #       return round(value,ndigits=1)
 #   else:
    if 'Price on Request' in value:
        return 'NA'
    else:
        emi =re.findall(r"[-+]?\d*\.\d+|\d+",value)
        return emi[-1]

# %%
df2['per_month_emi']=df2['emi'].apply(emi_splitter)

# %%
df2.drop(columns=['name','sq_ft','emi'],inplace=True)

# %%
df2.rename(columns={'final_BHK':'BHK'},inplace=True)

# %%
df2
# Out:
#                                                address  \
# 0    Aditya Apartment ,Swami Samarth Nagar, Nashik ...
# 1    Vasant Bahar,Pathardi Gaon, Pathardi Phata,Nashik
# 2                              Madhuban Colony, Nashik
# 3                           Janata Raja Colony, Nashik
# 4                                Deepali Nagar, Nashik
# ..                                                 ...
# 748                     Vasantdadanagar, Adgaon,Nashik
# 749                  Samarth Nagar, Makhmalabad,Nashik
# 750                             Bhor Town Ship, Nashik
# 751                                   Chandshi, Nashik
# 752                               Medage Nagar, Nashik
#
#                                     owners          housetype house_condition  \
# 0                              DisposalHub  Independent_house             old
# 1                    Dadasaheb Suryawanshi  Independent_house             old
# 2         Infinity Heights Private Limited  Independent_house             old
# 3                Prabhat Developers Nashik  Independent_house             old
# 4                      Shree Infra Project  Independent_house             old
# ..                                     ...                ...             ...
# 748                         Geeta Buildcon  Independent_house             old
# 749  Atharvashree Buildmat Private Limited  Independent_house             old
# 750               Shree Prakash Developers  Independent_house             old
# 751                           Nirman Group  Independent_house             old
# 752                          Ashoka Realty  Independent_house             old
#
#                 price      BHK total_sqft per_month_emi
# 0                30.0        2        835         15.89
# 1                32.0        2       1500         16.95
# 2               11.52     1, 2         NA          6.10
# 3               21.42     2, 3         NA         11.34
# 4               32.89     2, 3         NA         17.42
# ..                ...      ...        ...           ...
# 748  Price on Request        2         NA            NA
# 749             34.32        2         NA         18.17
# 750  Price on Request  1, 2, 3         NA            NA
# 751  Price on Request     2, 3         NA            NA
# 752             11.38        1         NA          6.02
#
# [753 rows x 8 columns]

# %%
df2.head(45)
# Out:
#                                               address  \
# 0   Aditya Apartment ,Swami Samarth Nagar, Nashik ...
# 1   Vasant Bahar,Pathardi Gaon, Pathardi Phata,Nashik
# 2                             Madhuban Colony, Nashik
# 3                          Janata Raja Colony, Nashik
# 4                               Deepali Nagar, Nashik
# 5                              Bhor Town Ship, Nashik
# 6                        Somwar Peth, Chandwad,Nashik
# 7   Dhanlaxmi row house,Krishna Nagar, MIDC Ambad,...
# 8                               Lamkhade Mala, Nashik
# 9               Bhujbal Knowledge City, Adgaon,Nashik
# 10                    Adhav Nagar, Nashik Road,Nashik
# 11                              Deepali Nagar, Nashik
# 12                   Ambedkar Nagar, Chunchale,Nashik
# 13                              Sagar Village, Nashik
# 14                                Makhmalabad, Nashik
# 15                            Kalpataru Nagar, Nashik
# 16     Gandhi Nagar Airport Area, Deolali Gaon,Nashik
# 17                                Makhmalabad, Nashik
# 18                                Makhmalabad, Nashik
# 19                   Kavnai village,Koknipura, Nashik
# 20          Saptashrungi Nagar, Kamatwade Gaon,Nashik
# 21                  Samarth Nagar, Makhmalabad,Nashik
# 22                               Ashwin Nagar, Nashik
# 23                 Raviwar Karanja, Panchavati,Nashik
# 24                      Prabudha Nagar, Satpur,Nashik
# 25                                Nashik Road, Nashik
# 26                                 Kalachowki, Nashik
# 27                                      Cidco, Nashik
# 28                    Pandavnagri, Mogal Nagar,Nashik
# 29                      Gulmohar Vihar, Satpur,Nashik
# 30                               Deolali Gaon, Nashik
# 31                               Mhasrul Gaon, Nashik
# 32                                MIDC, Satpur,Nashik
# 33                                Makhmalabad, Nashik
# 34      Prabhu Park ,Chetana Nagar, Rane Nagar,Nashik
# 35                                      Ojhar, Nashik
# 36                                   Gangapur, Nashik
# 37                                 Panchavati, Nashik
# 38                                 Panchavati, Nashik
# 39                               Savata Nagar, Nashik
# 40                          Cidco,Lekha Nagar, Nashik
# 41                   Shanti Nagar, Lekha Nagar,Nashik
# 42                 GajananNagar, Mahajan Nagar,Nashik
# 43                               Deolali Gaon, Nashik
# 44  Vatsalya Row Houses,Pandav Nagari, Pathardi Ph...
#
#                                 owners          housetype house_condition  \
# 0                          DisposalHub  Independent_house             old
# 1                Dadasaheb Suryawanshi  Independent_house             old
# 2     Infinity Heights Private Limited  Independent_house             old
# 3            Prabhat Developers Nashik  Independent_house             old
# 4                  Shree Infra Project  Independent_house             old
# 5             Shree Prakash Developers  Independent_house             old
# 6          Sheetal Javerilal Dungarwal  Independent_house             old
# 7                        Satish Jadhav  Independent_house             old
# 8                              Swapnil  Independent_house             old
# 9      Dinesh Bhai M Virmgama Builders  Independent_house             old
# 10               Dinesh Eknath Khandre  Independent_house             old
# 11                 Shree Infra Project  Independent_house             old
# 12                     Pearl Residency  Independent_house             old
# 13  Blue Ocean Builders And Developers  Independent_house             old
# 14                    Bhagya Developer  Independent_house             old
# 15                        Suhaib Logde  Independent_house             old
# 16     Sadguru Builders And Developers  Independent_house             old
# 17      J P Builders & Land Developers  Independent_house             old
# 18                        Jerry Dcunha  Independent_house             old
# 19                          Maa Sarada  Independent_house             old
# 20                              Chetan  Independent_house             old
# 21                        Rajesh Avhad  Independent_house             old
# 22                   Ashwin Laxmeshwar  Independent_house             old
# 23                               Mehul  Independent_house             old
# 24                       Rekha Vispute  Independent_house             old
# 25                            Prashant  Independent_house             old
# 26                     Girish Dhadiwal  Independent_house             old
# 27                               Sagar  Independent_house             old
# 28                         Bharat Aher  Independent_house             old
# 29              Jadhav Builders Nashik  Independent_house             old
# 30                    Surya Properties  Independent_house             old
# 31                B G Ambaliya Builder  Independent_house             old
# 32                    Chumble Builders  Independent_house             old
# 33                      Rakasheth Mali  Independent_house             old
# 34                                Ks S  Independent_house             old
# 35                        Eshak Shaikh  Independent_house             old
# 36              Peninsula Land Limited  Independent_house             old
# 37                        Vivek Shinde  Independent_house             old
# 38                        Vivek Shinde  Independent_house             old
# 39                               Mayur  Independent_house             old
# 40                             Santosh  Independent_house             old
# 41                     Arvind R Nagare  Independent_house             old
# 42                     Kishori Bhopale  Independent_house             old
# 43               Sainath Estate Agency  Independent_house             old
# 44                        Sanjay Dange  Independent_house             old
#
#                price      BHK total_sqft per_month_emi
# 0               30.0        2        835         15.89
# 1               32.0        2       1500         16.95
# 2              11.52     1, 2         NA          6.10
# 3              21.42     2, 3         NA         11.34
# 4              32.89     2, 3         NA         17.42
# 5              17.92  1, 2, 3         NA          9.49
# 6   Price on Request     1, 2         NA            NA
# 7               36.0        1        850         19.06
# 8               60.0        2       1300         31.77
# 9   Price on Request        2         NA            NA
# 10             39.26        3         NA         20.79
# 11             39.25     2, 3         NA         20.79
# 12  Price on Request        2         NA            NA
# 13  Price on Request        2         NA            NA
# 14              35.5  2, 3, 4         NA         18.80
# 15             100.0        2       1300         49.65
# 16             44.55        2         NA         23.59
# 17  Price on Request        2         NA            NA
# 18              37.0        2        850         19.59
# 19              27.0        1       1100         14.30
# 20              75.0        2        910         39.72
# 21              60.0        3       1650         31.77
# 22             200.0        1       1252         99.29
# 23             550.0        8      10000          2.73
# 24              56.0        5       1150         29.66
# 25              88.0        3        950         43.69
# 26              90.0        2       2500         44.68
# 27              90.0        5       1100         44.68
# 28              61.0        2       1250         32.30
# 29  Price on Request        2         NA            NA
# 30              40.0        2         NA         21.18
# 31  Price on Request        2         NA            NA
# 32  Price on Request   3, 3.5         NA            NA
# 33  Price on Request        2         NA            NA
# 34              70.0        2       1400         37.07
# 35              55.0        2       2300         29.13
# 36             165.0        4         NA         81.68
# 37              50.0        3       1300         26.48
# 38              65.0        3       1800         34.42
# 39              22.0        1        500         11.65
# 40              70.0        7       1000         37.07
# 41              35.0        3        800         18.53
# 42              47.0        2       1000         24.89
# 43             300.0        4       3200          1.49
# 44              32.0        1        980         16.95

# %%
df2.tail(50)
# Out:
#                                                address  \
# 703     Anand Vihar Colony, Veer Sawarkar Nagar,Nashik
# 704     Anand Vihar Colony, Veer Sawarkar Nagar,Nashik
# 705     Anand Vihar Colony, Veer Sawarkar Nagar,Nashik
# 706     Anand Vihar Colony, Veer Sawarkar Nagar,Nashik
# 707     Anand Vihar Colony, Veer Sawarkar Nagar,Nashik
# 708    Ashtavinayak Colony, Veer Sawarkar Nagar,Nashik
# 709                                TIDKE NAGAR, Nashik
# 710     Anand Vihar Colony, Veer Sawarkar Nagar,Nashik
# 711     Anand Vihar Colony, Veer Sawarkar Nagar,Nashik
# 712                                 Panchavati, Nashik
# 713                          Ashoknagar, Satpur,Nashik
# 714             Serene Meadows, Anandwalli Gaon,Nashik
# 715                    RTO Colony, Uttara Nagar,Nashik
# 716                 Raviwar Karanja, Panchavati,Nashik
# 717                 Raviwar Karanja, Panchavati,Nashik
# 718                             Ayodhya Nagari, Nashik
# 719    Ashtavinayak Colony, Veer Sawarkar Nagar,Nashik
# 720    Ashtavinayak Colony, Veer Sawarkar Nagar,Nashik
# 721            Datey Nagar, Veer Sawarkar Nagar,Nashik
# 722                 Lavate Nager, Parijat Nagar,Nashik
# 723                Mahatma Nagar, Parijat Nagar,Nashik
# 724                              Gaikwad Nagar, Nashik
# 725                Mahatma Nagar, Parijat Nagar,Nashik
# 726                          Ashoknagar, Satpur,Nashik
# 727                          Ashoknagar, Satpur,Nashik
# 728            Datey Nagar, Veer Sawarkar Nagar,Nashik
# 729            Swami Samarth Nagar, Nashik Road,Nashik
# 730            Swami Samarth Nagar, Nashik Road,Nashik
# 731                 Gayakhe Colony, Nashik Road,Nashik
# 732                               Balram Nagar, Nashik
# 733                                Nashik Road, Nashik
# 734  Omkar Construction,Damodar Nagar, Pathardi Pha...
# 735  Om sai row house,Pandav Nagari, Pathardi Phata...
# 736     Gandhi Nagar Airport Area, Deolali Gaon,Nashik
# 737                                      Ojhar, Nashik
# 738                Mahatma Nagar, Parijat Nagar,Nashik
# 739                 GajananNagar, Mahajan Nagar,Nashik
# 740                        Dhurav Nagar, Satpur,Nashik
# 741                  Samarth Nagar, Makhmalabad,Nashik
# 742                   Chetana Nagar, Rane Nagar,Nashik
# 743                                     Dwarka, Nashik
# 744                                   Gangapur, Nashik
# 745                                   Gangapur, Nashik
# 746              Bhujbal Knowledge City, Adgaon,Nashik
# 747              Prashant Nagar, Pathardi Phata,Nashik
# 748                     Vasantdadanagar, Adgaon,Nashik
# 749                  Samarth Nagar, Makhmalabad,Nashik
# 750                             Bhor Town Ship, Nashik
# 751                                   Chandshi, Nashik
# 752                               Medage Nagar, Nashik
#
#                                                 owners          housetype  \
# 703                                          Mr Sanjay  Independent_house
# 704                                          Mr Sanjay  Independent_house
# 705                                          Mr Sanjay  Independent_house
# 706                                          Mr Sanjay  Independent_house
# 707                                          Mr Sanjay  Independent_house
# 708                                          Mr Sanjay  Independent_house
# 709                                          Mr Sanjay  Independent_house
# 710                                          Mr Sanjay  Independent_house
# 711                                          Mr Sanjay  Independent_house
# 712                                          Mr Sanjay  Independent_house
# 713                                          Mr Sanjay  Independent_house
# 714                                          Mr Sanjay  Independent_house
# 715                                          Mr Sanjay  Independent_house
# 716                                            NISHANT  Independent_house
# 717                                            NISHANT  Independent_house
# 718                                 Agarwal Properties  Independent_house
# 719                                          Mr Sanjay  Independent_house
# 720                                          Mr Sanjay  Independent_house
# 721                                          Mr Sanjay  Independent_house
# 722                                          Mr Sanjay  Independent_house
# 723                                          Mr Sanjay  Independent_house
# 724                                          Mr Sanjay  Independent_house
# 725                                          Mr Sanjay  Independent_house
# 726                                          Mr Sanjay  Independent_house
# 727                                          Mr Sanjay  Independent_house
# 728                                          Mr Sanjay  Independent_house
# 729                                    Sajish Gangurde  Independent_house
# 730                                    Sajish Gangurde  Independent_house
# 731                                        Ejaj Sayyad  Independent_house
# 732                                    Sajish Gangurde  Independent_house
# 733                                        Ejaj Sayyad  Independent_house
# 734                                       Vinit Sawant  Independent_house
# 735                                        Vinod Yeram  Independent_house
# 736                                       Dales Estate  Independent_house
# 737                                     Jay Developers  Independent_house
# 738                     Rachita Constructions Pvt. Ltd  Independent_house
# 739                        Bhavani Construction Nashik  Independent_house
# 740                                 Shri Sanderi Group  Independent_house
# 741                                     Jay Developers  Independent_house
# 742  Bharatbhai Karsanbhai Adroja Contractors And D...  Independent_house
# 743                                    Reputed Builder  Independent_house
# 744                                    Reputed Builder  Independent_house
# 745                               Jai Durga Developers  Independent_house
# 746                                    Reputed Builder  Independent_house
# 747                                         Datta Kale  Independent_house
# 748                                     Geeta Buildcon  Independent_house
# 749              Atharvashree Buildmat Private Limited  Independent_house
# 750                           Shree Prakash Developers  Independent_house
# 751                                       Nirman Group  Independent_house
# 752                                      Ashoka Realty  Independent_house
#
#     house_condition             price      BHK total_sqft per_month_emi
# 703             old              40.0        2        822         21.18
# 704             old              40.0        2        822         21.18
# 705             old              30.0        1        854         15.89
# 706             old              56.0        3       1650         29.66
# 707             old              21.0        1        536         11.12
# 708             old              85.0        3       1725         42.20
# 709             old             140.0        4       2310         69.50
# 710             old              27.0        1        640         14.30
# 711             old             111.0        3       2200         55.11
# 712             old             110.0        3       1740         54.61
# 713             old              70.0        3       1600         37.07
# 714             old             200.0        3       2100         99.29
# 715             old             135.0        4       2800         67.02
# 716             old             211.0        4       3000          1.05
# 717             old              51.0        1       1411         27.01
# 718             old             350.0        4       1000          1.74
# 719             old              34.0        2        970         18.00
# 720             old              45.0        2       1050         23.83
# 721             old              60.0        3       1325         31.77
# 722             old              30.0        1        750         15.89
# 723             old              28.5        1        816         15.09
# 724             old              55.0        2        924         29.13
# 725             old              28.5        1        816         15.09
# 726             old              75.0        3       1200         39.72
# 727             old              55.0        2       1420         29.13
# 728             old              34.0        2        970         18.00
# 729             old              40.0        2       1400         21.18
# 730             old              40.0        2       1400         21.18
# 731             old              55.0        2       1650         29.13
# 732             old              45.0        4       1450         23.83
# 733             old             57.51        3       1475         30.45
# 734             old              15.0        1        525          7.94
# 735             old              41.0        2       1000         21.71
# 736             old  Price on Request        3         NA            NA
# 737             old             38.75        3         NA         20.52
# 738             old              56.5        2         NA         29.92
# 739             old  Price on Request        2         NA            NA
# 740             old  Price on Request     3, 4         NA            NA
# 741             old              45.5      3.5         NA         24.09
# 742             old  Price on Request        2         NA            NA
# 743             old  Price on Request        5         NA            NA
# 744             old  Price on Request   2, 2.5         NA            NA
# 745             old  Price on Request        2         NA            NA
# 746             old  Price on Request        2         NA            NA
# 747             old             92.25        4         NA         45.80
# 748             old  Price on Request        2         NA            NA
# 749             old             34.32        2         NA         18.17
# 750             old  Price on Request  1, 2, 3         NA            NA
# 751             old  Price on Request     2, 3         NA            NA
# 752             old             11.38        1         NA          6.02

# %%
df2.to_csv('data8')

# %%
import pandas as pd

# %%
df1= pd.read_csv('housing_data1',index_col=0)

# %%
df1
# Out:
#                                             name     price  \
# 0             2 BHK Apartment for sale in Niphad  ₹11.49 L
# 1        2 BHK Apartment for sale in Samta Nagar   ₹35.0 L
# 2        3 BHK Apartment for sale in Samta Nagar  ₹46.99 L
# 3             1 BHK Apartment for sale in Niphad  ₹12.85 L
# 4        3 BHK Apartment for sale in Samta Nagar   ₹42.0 L
# ..                                           ...       ...
# 464      1 BHK Apartment for sale in Nashik Road   ₹21.0 L
# 465      2 BHK Apartment for sale in Nashik Road   ₹55.0 L
# 466      2 BHK Apartment for sale in Nashik Road   ₹23.0 L
# 467  2 BHK Apartment for sale in Vrindavan Nagar   ₹28.0 L
# 468           2 BHK Apartment for sale in Satpur  ₹38.51 L
#
#                                      address       sq_ft  \
# 0            Renuka Apartment,Niphad, Nashik   520 sq.ft
# 1    Samraat Dream Citi, Samta Nagar, Nashik   945 sq.ft
# 2    Samraat Dream Citi, Samta Nagar, Nashik  1160 sq.ft
# ...

# %%
df2= pd.read_csv('housing_data2',index_col=0)
df3= pd.read_csv('housing_data3',index_col=0)
df4= pd.read_csv('housing_data4',index_col=0)
df5= pd.read_csv('housing_data5',index_col=0)
df6= pd.read_csv('housing_data6',index_col=0)
df7= pd.read_csv('housing_data7',index_col=0)
df8= pd.read_csv('housing_data8',index_col=0)

# %%
frames = [df1,df2,df3,df4,df5,df6,df7,df8]

# %%
df2.head(4)
# Out:
#                                           name                   address  \
# 0                                 Bhavik Arina     Navnath Nagar, Nashik
# 1  AK Aadinath Row Houses And Addinath Heights   CDO-MERI Colony, Nashik
# 2                       Shree Radhe Vraj Bhumi  Shivshakti Nagar, Nashik
# 3                 Shree Krushna Rajaram Palace       Vijay Nagar, Nashik
#
#                     sq_ft                                 owners  \
# 0  1, 2, 3 BHK Apartments                           Bhavik Group
# 1     1, 2 BHK Apartments             AK Builders And Developers
# 2         3 BHK Apartment               Shree Radhe Construction
# 3     1, 2 BHK Apartments  Shree Krushna Builders And Developers
#
#                                           emi  housetype house_condition
# 0  ₹20.07 L - 37.32 L\nEMI starts at ₹10.63 K  Apartment             old
# 1                            Price on Request  Apartment             old
# ...

# %%
df3.head(4)
# Out:
#                                                name  \
# 0  3 BHK Apartment for sale in Dr.Homi Bhabha Nagar
# 1           2 BHK Apartment for sale in Samta Nagar
# 2           2 BHK Apartment for sale in Nashik Road
# 3           2 BHK Apartment for sale in Nashik Road
#
#                                              address       sq_ft  \
# 0  Sheetal Vihar, Bhagwant Nagar, Dr.Homi Bhabha ...  1550 sq.ft
# 1            Samraat Dream Citi, Samta Nagar, Nashik  1000 sq.ft
# 2         Suryaprakash Apartment,Nashik Road, Nashik   970 sq.ft
# 3             Adishvar Residency,Nashik Road, Nashik  1000 sq.ft
#
#             owners                               emi  housetype  \
# 0  Mahendra Kotwal   ₹75.0 L\nEMI starts at ₹39.72 K  Apartment
# 1   Jiten Dadarkar   ₹41.0 L\nEMI starts at ₹21.71 K  Apartment
# 2           Pankaj  ₹53.35 L\nEMI starts at ₹28.25 K  Apartment
# 3           Saurav   ₹55.0 L\nEMI starts at ₹29.13 K  Apartment
#
#   house_condition
# 0             old
# ...

# %%
df4.head(4)
# Out:
#                                          name  \
# 0                      Ashoka Atharva Heights
# 1    2 BHK Apartment for sale in Indira Nagar
# 2  3 BHK Apartment for sale in Pathardi Phata
# 3    3 BHK Apartment for sale in Indira Nagar
#
#                                              address                sq_ft  \
# 0                                 Nashik Road,Nashik  2, 3 BHK Apartments
# 1       Nerkar Ganesh Signifia, Indira Nagar, Nashik            980 sq.ft
# 2  Karda Hari Vishwa, Buddha Vihar, Pathardi Phat...           1600 sq.ft
# 3  Sanklecha The Metrozone, Kala Nagar, Indira Na...           1918 sq.ft
#
#           owners                                         emi  housetype  \
# 0  Ashoka Realty  ₹21.51 L - 38.01 L\nEMI starts at ₹11.39 K  Apartment
# 1  Sumit Acharya             ₹43.0 L\nEMI starts at ₹22.77 K  Apartment
# 2   Ganesh Gorhe             ₹59.5 L\nEMI starts at ₹31.51 K  Apartment
# ...

# %%
df5.head(4)
# Out:
#                       name                                          avg_price  \
# 0             Suyojit Baug  Configuration\n3 BHK Apartment\nPossession Sta...
# 1          Vaastu's gaurav  Configuration\n3.5 BHK Apartment\nPossession S...
# 2  Compact Ambika Paradise  Configuration\n2 BHK Apartment\nPossession Sta...
# 3     Mahalaxmi Park Woods  Configuration\n3 BHK Apartment\nPossession Sta...
#
#                 address              sq_ft                           owners  \
# 0  Sahdev Nagar, Nashik    3 BHK Apartment  Suyojit Infrastructure Pvt Ltd.
# 1  Sahdev Nagar, Nashik  3.5 BHK Apartment                     Vaastu Group
# 2  Ekdant Nagar, Nashik    2 BHK Apartment    Compact Builders & Developers
# 3   D. K. Nagar, Nashik    3 BHK Apartment             Mahalaxmi Associates
#
#                                           emi
# 0  ₹1.47 Cr - 1.59 Cr\nEMI starts at ₹73.22 K
# 1            ₹94.35 L\nEMI starts at ₹46.84 K
# 2            ₹21.15 L\nEMI starts at ₹11.20 K
# ...

# %%
df6.head(4)
# Out:
#                                       name  \
# 0    2 BHK Apartment for sale in Vaiduwadi
# 1       3 BHK Apartment for sale in Satpur
# 2  2 BHK Apartment for sale in Nashik Road
# 3  3 BHK Apartment for sale in Nashik Road
#
#                                       address       sq_ft  \
# 0              Pokar Colony, Vaiduwadi,Nashik   923 sq.ft
# 1          Mblu 2,Ganesh Nagar, Satpur,Nashik  1900 sq.ft
# 2                   Ozone,Nashik Road, Nashik  1044 sq.ft
# 3  Anmol Nayantara Estate,Nashik Road, Nashik  1808 sq.ft
#
#                      owners                               emi  housetype  \
# 0           Satendra Pandey   ₹27.5 L\nEMI starts at ₹14.56 K  Apartment
# 1  Metadesign India Pvt Ltd   ₹75.0 L\nEMI starts at ₹39.72 K  Apartment
# 2            M L Developers  ₹42.11 L\nEMI starts at ₹22.30 K  Apartment
# 3                     Rupak   ₹1.1 Cr\nEMI starts at ₹54.61 K  Apartment
#
#   house_condition
# 0             new
# 1             new
# 2             new
# ...

# %%
df7.tail(45)
# Out:
#                                                   name  \
# 708  3 BHK Independent House for sale in Veer Sawar...
# 709  4 BHK Independent Builder Floor for sale in TI...
# 710  1 BHK Independent Builder Floor for sale in Ve...
# 711  3 BHK Independent House for sale in Veer Sawar...
# 712     3 BHK Independent House for sale in Panchavati
# 713         3 BHK Independent House for sale in Satpur
# 714  3 BHK Independent House for sale in Anandwalli...
# 715   4 BHK Independent House for sale in Uttara Nagar
# 716     4 BHK Independent House for sale in Panchavati
# 717  1 BHK Independent Builder Floor for sale in Pa...
# 718  4 BHK Independent Builder Floor for sale in Ay...
# 719  2 BHK Independent Builder Floor for sale in Ve...
# 720  2 BHK Independent Builder Floor for sale in Ve...
# 721  3 BHK Independent Builder Floor for sale in Ve...
# 722  1 BHK Independent Builder Floor for sale in Pa...
# 723  1 BHK Independent Builder Floor for sale in Pa...
# ...

# %%
df8.head(45)
# Out:
#                                               address  \
# 0                 Asha Bramha Greens, Trimbak, Nashik
# 1     Samraat Dream Villas, Ganesh Baba Nagar, Nashik
# 2           Viveka Nand Nagar, Anandwalli Gaon,Nashik
# 3                 Asha Bramha Greens, Trimbak, Nashik
# 4                 Asha Bramha Greens, Trimbak, Nashik
# 5   Bramha Greens Farm House Project ,Trimbak, Nashik
# 6                 Asha Bramha Greens, Trimbak, Nashik
# 7                      Adke Nagar, Nashik Road,Nashik
# 8                                      Koroli, Nashik
# 9                                  Asha Nagar, Nashik
# 10                          Ganesh Baba Nagar, Nashik
# 11                                 Asha Nagar, Nashik
# 12                                Uttam Nagar, Nashik
# 13                                   Chandshi, Nashik
# 14                                     Dwarka, Nashik
# 15                Buddha Vihar, Pathardi Phata,Nashik
# ...

# %%
df1.head(4)
# Out:
#                                       name     price  \
# 0       2 BHK Apartment for sale in Niphad  ₹11.49 L
# 1  2 BHK Apartment for sale in Samta Nagar   ₹35.0 L
# 2  3 BHK Apartment for sale in Samta Nagar  ₹46.99 L
# 3       1 BHK Apartment for sale in Niphad  ₹12.85 L
#
#                                    address       sq_ft         owners  \
# 0          Renuka Apartment,Niphad, Nashik   520 sq.ft    DisposalHub
# 1  Samraat Dream Citi, Samta Nagar, Nashik   945 sq.ft  Sumit Acharya
# 2  Samraat Dream Citi, Samta Nagar, Nashik  1160 sq.ft  Kartik Peshwe
# 3          Renuka Apartment,Niphad, Nashik   520 sq.ft    DisposalHub
#
#                       emi house_condition  housetype
# 0   EMI starts at ₹6.09 K             old  Apartment
# 1  EMI starts at ₹18.53 K             old  Apartment
# 2  EMI starts at ₹24.88 K             old  Apartment
# 3   EMI starts at ₹6.80 K             old  Apartment

# %%
nashik = pd.concat(frames,ignore_index=True)

# %%
nashik.head(45)
# Out:
#                                             name     price  \
# 0             2 BHK Apartment for sale in Niphad  ₹11.49 L
# 1        2 BHK Apartment for sale in Samta Nagar   ₹35.0 L
# 2        3 BHK Apartment for sale in Samta Nagar  ₹46.99 L
# 3             1 BHK Apartment for sale in Niphad  ₹12.85 L
# 4        3 BHK Apartment for sale in Samta Nagar   ₹42.0 L
# 5        2 BHK Apartment for sale in Wadala Gaon   ₹45.0 L
# 6        2 BHK Apartment for sale in Nashik Road   ₹28.0 L
# 7    2 BHK Apartment for sale in Kalpataru Nagar   ₹45.0 L
# 8    2 BHK Apartment for sale in Kalpataru Nagar   ₹63.0 L
# 9        2 BHK Apartment for sale in Samta Nagar   ₹37.0 L
# 10       2 BHK Apartment for sale in Samta Nagar  ₹37.51 L
# 11       1 BHK Apartment for sale in Nashik Road   ₹35.5 L
# 12       1 BHK Apartment for sale in Makhmalabad   ₹15.5 L
# 13      2 BHK Apartment for sale in Sharda Vihar   ₹46.0 L
# 14         2 BHK Apartment for sale in Amrutdham   ₹28.5 L
# ...

# %%
nashik.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5724 entries, 0 to 5723
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             5303 non-null   object
#  1   price            890 non-null    object
#  2   address          5724 non-null   object
#  3   sq_ft            5303 non-null   object
#  4   owners           5711 non-null   object
#  5   emi              5303 non-null   object
#  6   house_condition  4944 non-null   object
#  7   housetype        4944 non-null   object
#  8   avg_price        780 non-null    object
#  9   BHK              413 non-null    object
#  10  total_sqft       383 non-null    float64
# dtypes: float64(1), object(10)
# memory usage: 492.0+ KB

# %%
nashik.describe(include='all')
# Out:
#                                            name    price              address  \
# count                                      5303      890                 5724
# unique                                     2350      279                 1784
# top     2 BHK Apartment for sale in Nashik Road  ₹35.0 L  Nashik Road, Nashik
# freq                                        298       28                  300
# mean                                        NaN      NaN                  NaN
# std                                         NaN      NaN                  NaN
# min                                         NaN      NaN                  NaN
# 25%                                         NaN      NaN                  NaN
# 50%                                         NaN      NaN                  NaN
# 75%                                         NaN      NaN                  NaN
# max                                         NaN      NaN                  NaN
#
# ...

# %%
nashik.shape
# Out:
# (5724, 11)

# %%
nashik.isnull().sum()
# Out:
# name                421
# price              4834
# address               0
# sq_ft               421
# owners               13
# emi                 421
# house_condition     780
# housetype           780
# avg_price          4944
# BHK                5311
# total_sqft         5341
# dtype: int64

# %%
len(nashik['name'].unique())
# Out:
# 2491

# %%
nashik.tail(40)
# Out:
#      name             price                                        address  \
# 5684  NaN              68.4                           Kishor Nagar, Nashik
# 5685  NaN              65.0                Kala Nagar, Indira Nagar,Nashik
# 5686  NaN             14.85                              Ghatkopar, Nashik
# 5687  NaN             100.0                                 Dwarka, Nashik
# 5688  NaN              40.0        Swami Samarth Nagar, Nashik Road,Nashik
# 5689  NaN              42.0  Gandhi Nagar Airport Area, Nashik Road,Nashik
# 5690  NaN              60.0                            Nashik Road, Nashik
# 5691  NaN              51.0                               Chandshi, Nashik
# 5692  NaN              27.0              Vinayak Row Houses ,Ojhar, Nashik
# 5693  NaN              65.0                Adhav Nagar, Nashik Road,Nashik
# 5694  NaN             172.0             Raviwar Karanja, Panchavati,Nashik
# ...
